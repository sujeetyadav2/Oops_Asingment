# %% [markdown]
# # THEORY QUESTIONS #

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
#   Ans:- OOP is a programming paradigm that organizes software using objects, which bundle:
#
#       Data (attributes)
#
#       Behavior (methods)
#
#    Why OOP exists?
#
#       Models real-world entities
#
#       Improves code reusability
#
#       Makes systems scalable and maintainable
#
#    Core pillars of OOP
#
#       Encapsulation
#
#       Abstraction
#
#       Inheritance
#
#
#       Polymorphism

# %% [markdown]
# 2. What is a class in OOP?
#
#   Ans :- A class is a blueprint for creating objects.
#
#    class Car:
#     def drive(self):
#         print("Car is moving")
#
#    Defines structure
#    No memory allocated until object is created

# %% [markdown]
# 3. What is an object in OOP?
#
#   Ans :- c1 = Car()
#        c1.drive()
#
#
#    Occupies memory
#
#    Can access class methods and variables

# %% [markdown]
# Q4. What is the difference between abstraction and encapsulation?
#
#   Ans:- Abstraction -
#
#          Hides implementation
#
#          Focus on what
#
#          Achieved via abstract classes
#
#      Encapsulation -
#
#          Hides data
#
#          Focus on how
#
#          Achieved via access modifiers

# %% [markdown]
# Q5. What are dunder methods in Python?
#
#   Ans:- Double underscore methods (__method__) are special Python methods.
#
#         Examples:
#
#        1.  __init__ → constructor
#
#        2.  __str__ → string display
#
#        3.  __add__ → operator overloading
#
#        def __str__(self):
#     return "Object info"

# %% [markdown]
# Q6. Explain the concept of inheritance in OOP.
#
#   Ans:- Inheritance allows a class to reuse another class’s functionality.
#
#         class Dog(Animal):
#     pass
#
#          Types:
#
#            0. Single
#
#            1. Multilevel
#
#            2. Multiple
#
#            3. Hierarchical

# %% [markdown]
# Q7. What is polymorphism in OOP?
#
#   Ans:- Polymorphism = same method name, different behavior
#
#         animal.speak()
#
#         Different outputs depending on object type.

# %% [markdown]
# Q8. How is encapsulation achieved in Python?
#
#   Ans:- By using:
#
#           1. Private variables (__var)
#
#           2. Public methods to access them
#
#
#         self.__balance

# %% [markdown]
# Q9. What is a constructor in Python?
#
#   Ans:- A constructor initializes an object.
#
#         def __init__(self, name):
#     self.name = name
#
#
#     Automatically called when object is created

# %% [markdown]
# Q10. What are class methods and static methods in Python?
#
#   Ans:- Class Method-
#
#          1. Uses cls
#
#          2. Works on class variables
#
#          3. Decorator @classmethod
#
#     Static Method-
#
#          1. No self or cls
#
#          2. Utility function
#
#          3. @staticmethod

# %% [markdown]
# Q11. What is method overloading in Python?
#
#   Ans:- Python does not support traditional overloading.
#
#         Achieved using:
#
#          1. Default arguments
#
#          2. *args

# %% [markdown]
# Q12. What is method overriding in OOP?
#
# Answer:
#
#   Method overriding occurs when a child class provides a different implementation of a method already defined in the parent class.

# %% [markdown]
# Q13. What is a property decorator in Python?
#
#   Ans:- The @property decorator allows a method to be accessed like an attribute.
# It is mainly used to implement getters and setters.

# %% [markdown]
# Q14. Why is polymorphism important in OOP?
#
#  Ans:- Polymorphism improves-
#
#         1. Flexibility
#
#         2. Code readability
#
#         3. Extensibility
#
#     It allows the same interface to be used for different data types.

# %% [markdown]
# Q15. What is an abstract class in Python?
#
#   Ans:- 1. An abstract class is a class that contains abstract methods and cannot be instantiated.
#
#      2. It is used to define a common interface for child classes.

# %% [markdown]
# Q16. What are the advantages of OOP?
#
#   Ans:- Advantages of OOP include:-
#          1. Code reusability
#
#          2. Modularity
#
#          3. Data security
#
#          4. Easy maintenance
#
#          5. Scalability

# %% [markdown]
# Q17. Difference between class variable and instance variable?
#
#   Ans:- Class Variable-
#
#           1. Shared by all objects
#
#           2. Defined inside class
#
#      Instance Variable-
#
#           1. Unique to each object
#
#           2. Defined inside constructor

# %% [markdown]
# Q18. What is multiple inheritance in Python?
#
#   Ans:- Multiple inheritance allows a class to inherit from more than one parent class.

# %% [markdown]
# Q19. Purpose of __str__ and __repr__ methods?
#
#   Ans:- 1. __str__ returns user-friendly string
#
#      2. __repr__ returns developer-friendly string

# %% [markdown]
# Q20. Significance of super() function?
#
#   Ans:- super() is used to call parent class methods from a child class.

# %% [markdown]
# Q21. Significance of __del__ method?
#
#   Ans:- The __del__ method is a destructor that is called when an object is deleted.

# %% [markdown]
# Q22. Difference between @staticmethod and @classmethod?
#
#   Ans:- 1. Static method does not access class or instance
#
#      2. Class method accesses class variables using cls

# %% [markdown]
# Q23. How does polymorphism work with inheritance?
#
#   Ans:- Polymorphism works using method overriding, where child class methods replace parent class methods at runtime.

# %% [markdown]
# Q24. What is method chaining in Python OOP?
#
#   Ans:- Method chaining allows multiple methods to be called on the same object in a single line.

# %% [markdown]
# Q25. What is the purpose of __call__ method?
#
#   Ans:- The __call__ method allows an object to be called like a function.

# %% [markdown]
# # PRACTICAL QUESTIONS #

# %%
#Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

obj = Dog()
obj.speak()
# Out:
# Dog barks

# %%
#Q2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def area(self):
        length = 10
        breadth = 5
        return length * breadth

obj = Rectangle()
print(obj.area())
# Out:
# 50

# %%
#Q3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
    def show_type(self):
        print("This is a vehicle")

class Car(Vehicle):
    def show_car(self):
        print("This is a car")

class ElectricCar(Car):
    def show_electric(self):
        print("This is an electric car")

obj = ElectricCar()
obj.show_type()
obj.show_car()
obj.show_electric()
# Out:
# This is a vehicle
# This is a car
# This is an electric car

# %%
#Q4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Ostrich(Bird):
    def fly(self):
        print("Ostrich cannot fly")

for bird in (Sparrow(), Ostrich()):
    bird.fly()
# Out:
# Sparrow flies high
# Ostrich cannot fly

# %%
#Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def show_balance(self):
        print("Balance:", self.__balance)

obj = BankAccount()
obj.deposit(1000)
obj.show_balance()
# Out:
# Balance: 1000

# %%
#Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
class Instrument:
    def play(self):
        pass

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

for obj in (Guitar(), Piano()):
    obj.play()
# Out:
# Guitar is playing
# Piano is playing

# %%
#Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:
    @classmethod
    def add(cls, a, b):
        return a + b

    @staticmethod
    def subtract(a, b):
        return a - b

print(MathOperations.add(10, 5))
print(MathOperations.subtract(10, 5))
# Out:
# 15
# 5

# %%
#Q8. Implement a class Person with a class method to count the total number of persons created.
class Student:
    count = 0

    def __init__(self):
        Student.count += 1

s1 = Student()
s2 = Student()
s3 = Student()

print("Total objects:", Student.count)
# Out:
# Total objects: 3

# %%
#Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, n, d):
        self.n = n
        self.d = d

    def __str__(self):
        return f"{self.n}/{self.d}"

obj = Fraction(3, 4)
print(obj)
# Out:
# 3/4

# %%
#Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.class Fraction:
class Vector:
    def __init__(self, x):
        self.x = x

    def __add__(self, other):
        return self.x + other.x

v1 = Vector(10)
v2 = Vector(20)
print(v1 + v2)
# Out:
# 30

# %%
#Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Rahul", 22)
p.greet()
# Out:
# Hello, my name is Rahul and I am 22 years old.

# %%
#Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Aman", [80, 90, 85])
print(s.average_grade())
# Out:
# 85.0

# %%
#Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def set_dimensions(self, l, b):
        self.length = l
        self.breadth = b

    def area(self):
        return self.length * self.breadth

r = Rectangle()
r.set_dimensions(10, 5)
print(r.area())
# Out:
# 50

# %%
#Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate):
        return super().calculate_salary(hours, rate) + 2000

m = Manager()
print(m.calculate_salary(40, 500))
# Out:
# 22000

# %%
#Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() thatcalculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Pen", 10, 5)
print(p.total_price())
# Out:
# 50

# %%
#Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

Cow().sound()
Sheep().sound()
# Out:
# Moo
# Baa

# %%
#Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, Published in {self.year}"

b = Book("Python", "Guido", 1991)
print(b.get_book_info())
# Out:
# Python by Guido, Published in 1991

# %%
#Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

m = Mansion("Delhi", 5000000, 10)
print(m.address, m.price, m.rooms)
# Out:
# Delhi 5000000 10
